# %% [markdown]
# ### Lection explring

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import opencv_jupyter_ui as jcv2

# %%
# %pip install opencv_jupyter_ui
# %pip install ipycanvas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
cap = cv2.VideoCapture("data/video_cat.mp4")
ret, prev = cap.read()
prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY)
while True:
    ret, frame = cap.read()
    if not ret: break
        
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    It = cv2.absdiff(gray, prev_gray)
    jcv2.imshow("Frame", gray.view(), colorspace='gray')
    jcv2.imshow("Temporal difference |It|", It, colorspace='gray')
    
    prev_gray = gray.copy()
    if cv2.waitKey(1) & 0xFF == ord('q'): break

# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File D:\Alex\GitHub\CV\venv\lib\site-packages\PIL\ImageFile.py:648, in _save(im, fp, tile, bufsize)
#     647 try:
# --> 648     fh = fp.fileno()
#     649     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       8 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9 It = cv2.absdiff(gray, prev_gray)
# ---> 10 jcv2.imshow("Frame", gray.view(), colorspace='gray')
#      11 jcv2.imshow("Temporal difference |It|", It, colorspace='gray')
#      13 prev_gray = gray.copy()
#
# File D:\Alex\GitHub\CV\venv\lib\site-packages\opencv_jupyter_ui\cv2_imshow.py:83, in cv2_imshow(name, image, width, height, colorspace, force_clear)
# ...

# %%
gray.reshape(-1, 1).shape
# Out:
# (589824, 1)
